# %% [markdown]
# <a href="https://colab.research.google.com/github/swatia600/IT_Salary_Survey/blob/main/Stat650.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/swatia600/IT_Salary_Survey/main/T%20Salary%20Survey%20EU%202019.csv')

# %%
df1
# Out:
#              Zeitstempel   Age Gender       City Seniority level  \
# 0    02.12.2019 11:18:26  33.0   Male     Berlin          Senior
# 1    02.12.2019 11:18:35  29.0   Male     Berlin          Middle
# 2    02.12.2019 11:18:56   NaN   Male     Berlin          Middle
# 3    02.12.2019 11:19:08  30.0   Male     Berlin          Senior
# 4    02.12.2019 11:19:37  32.0   Male     Berlin          Senior
# ..                   ...   ...    ...        ...             ...
# 986  07.01.2020 09:23:01  30.0   Male  Amsterdam          Senior
# 987  07.01.2020 10:08:18  28.0   Male  Amsterdam          Senior
# 988  07.01.2020 16:52:43  42.0   Male     Munich          Senior
# 989  08.01.2020 11:18:41  33.0   Male     Berlin          Senior
# 990  08.01.2020 22:20:08  32.0   Male  Frankfurt          Middle
#
#     Position (without seniority)  Years of experience  \
# 0            Fullstack Developer                   13
# 1              Backend Developer                    3
# ...

# %%
df1.shape()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ba1842de51e0> in <module>
# ----> 1 df1.shape()
#
# NameError: name 'df1' is not defined

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/swatia600/IT_Salary_Survey/main/IT%20Salary%20Survey%20EU%202018.csv')

# %%
df2
# Out:
#                Timestamp   Age Gender     City                       Position  \
# 0    14/12/2018 12:41:33  43.0      M  München                   QA Ingenieur
# 1    14/12/2018 12:42:09  33.0      F  München  Senior PHP Magento developer
# 2    14/12/2018 12:47:36  32.0      M  München              Software Engineer
# 3    14/12/2018 12:50:15  25.0      M  München      Senior Frontend Developer
# 4    14/12/2018 12:50:31  39.0      M  München                    UX Designer
# ..                   ...   ...    ...      ...                            ...
# 760  03/06/2020 20:12:51  40.0      M     Köln          Java Developer junior
# 761  28/07/2020 04:03:13   NaN      M     Köln              E.g. C# Developer
# 762  28/07/2020 04:03:20   NaN      M     Köln              E.g. C# Developer
# 763  26/08/2020 09:06:44   NaN    NaN      NaN                            NaN
# 764  21/09/2020 01:47:10  31.0      F  München                            Pm
#
# ...

# %%
https://github.com/swatia600/IT_Salary_Survey/tree/main/data_files
